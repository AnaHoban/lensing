# %%
import os
import h5py
import shutil
import pandas as pd
from astropy.nddata.utils import Cutout2D
from astropy.io import fits
from astropy import table
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import (ZScaleInterval, ImageNormalize)
from astropy.visualization import make_lupton_rgb
from collections import Counter
from tensorflow import keras
from astropy.wcs import WCS,utils

from functions import train_autoencoder

# %% [markdown]
# # Initialize hdf5 file

# %%
os.path.expandvars("$SLURM_TMPDIR")
# Out:
# '/localscratch/anahoban.5043391.0'

# %%
hf = h5py.File(os.path.expandvars("$SCRATCH")+"/labelled_cutouts_64p.h5", "w")
hf.close()

# %%
src = os.path.expandvars("$SCRATCH") + "/labelled_cutouts_64p.h5"
dest = os.path.expandvars("$SLURM_TMPDIR") + "/"
shutil.copy2(src, dest)
# Out:
# '/localscratch/anahoban.5043391.0/labelled_cutouts_64p.h5'

# %%
dest = os.path.expandvars("$SLURM_TMPDIR") + "/"
hf = h5py.File(dest + "labelled_cutouts_64p.h5", "r+")

# %%
#hf.close()

# %% [markdown]
# ### Looking at the candidates

# %%
image_dir = "/home/anahoban/projects/rrg-kyi/astro/cfis/W3/"
label_dir = "labels/"

# %%
tile_file = open(image_dir + "tiles_cand.list", "r")
tile_list = tile_file.readlines()
for i in range(len(tile_list)):
    tile_list[i] = tile_list[i][:-1] # Remove new line characters
    print(tile_list[i])
tile_file.close()
# Out:
# CFIS.000.184.u
# CFIS.000.187.u
# CFIS.000.223.u
# CFIS.000.226.u
# CFIS.001.234.u
# CFIS.002.208.u
# CFIS.003.190.u
# CFIS.003.212.u
# CFIS.004.180.u
# CFIS.004.183.u
# CFIS.004.217.u
# CFIS.005.216.u
# CFIS.005.217.u
# CFIS.006.182.u
# CFIS.007.184.u
# CFIS.007.203.u
# CFIS.007.229.u
# CFIS.008.244.r
# CFIS.008.244.u
# CFIS.009.202.u
# CFIS.009.213.u
# CFIS.010.210.u
# CFIS.011.180.u
# CFIS.011.184.u
# CFIS.012.180.u
# CFIS.012.183.u
# CFIS.012.187.u
# CFIS.012.228.u
# CFIS.013.187.u
# CFIS.013.189.u
# CFIS.013.191.u
# CFIS.013.200.u
# CFIS.013.210.u
# CFIS.013.214.u
# CFIS.013.231.u
# CFIS.013.259.u
# CFIS.014.193.u
# CFIS.015.204.u
# CFIS.016.179.u
# CFIS.016.182.u
# CFIS.016.195.u
# CFIS.016.203.u
# CFIS.017.185.u
# CFIS.017.189.u
# CFIS.018.182.u
# CFIS.018.198.u
# CFIS.019.195.u
# CFIS.019.219.u
# CFIS.019.237.u
# CFIS.020.181.u
# CFIS.021.179.u
# CFIS.021.203.u
# CFIS.022.182.u
# CFIS.022.191.u
# CFIS.022.200.u
# CFIS.025.190.u
# CFIS.025.202.u
# CFIS.027.188.u
# CFIS.027.197.u
# CFIS.027.223.u
# CFIS.028.179.u
# CFIS.028.180.u
# CFIS.028.186.u
# CFIS.028.228.u
# CFIS.028.234.u
# CFIS.029.179.u
# CFIS.029.180.u
# CFIS.029.181.u
# CFIS.029.192.u
# CFIS.029.194.u
# CFIS.029.207.u
# CFIS.029.212.u
# CFIS.029.217.u
# CFIS.030.179.u
# CFIS.030.180.u
# CFIS.030.184.u
# CFIS.030.187.u
# CFIS.031.179.u
# CFIS.031.180.u
# CFIS.031.181.u
# CFIS.031.186.u
# CFIS.032.179.u
# CFIS.032.180.u
# CFIS.032.181.u
# CFIS.033.180.u
# CFIS.033.181.u
# CFIS.033.182.u
# CFIS.033.183.u
# CFIS.033.184.u
# CFIS.033.186.u
# CFIS.033.190.u
# CFIS.033.219.u
# CFIS.034.179.u
# CFIS.034.181.u
# CFIS.034.183.u
# CFIS.034.186.u
# CFIS.034.208.u
# CFIS.034.210.u
# CFIS.035.188.u
# CFIS.035.198.u
# CFIS.035.202.u
# CFIS.035.208.u
# CFIS.035.235.u
# CFIS.035.249.r
# CFIS.035.249.u
# CFIS.036.180.u
# CFIS.036.185.u
# CFIS.036.186.u
# CFIS.036.219.u
# CFIS.036.242.r
# CFIS.036.242.u
# CFIS.037.187.u
# CFIS.038.180.u
# CFIS.038.223.u
# CFIS.038.262.u
# CFIS.039.187.u
# CFIS.040.238.r
# CFIS.040.238.u
# CFIS.041.179.u
# CFIS.041.180.u
# CFIS.041.251.r
# CFIS.041.251.u
# CFIS.042.180.u
# CFIS.042.188.u
# CFIS.043.179.u
# CFIS.044.180.u
# CFIS.045.180.u
# CFIS.045.181.u
# CFIS.045.228.u
# CFIS.046.187.u
# CFIS.046.224.u
# CFIS.047.189.u
# CFIS.047.190.u
# CFIS.048.180.u
# CFIS.048.181.u
# CFIS.048.183.u
# CFIS.048.192.u
# CFIS.049.186.u
# CFIS.049.189.u
# CFIS.049.210.u
# CFIS.049.225.u
# CFIS.049.235.u
# CFIS.050.212.u
# CFIS.051.195.u
# CFIS.051.206.u
# CFIS.051.224.u
# CFIS.051.245.r
# CFIS.051.245.u
# CFIS.052.182.u
# CFIS.052.190.u
# CFIS.052.191.u
# CFIS.052.201.u
# CFIS.052.239.r
# CFIS.052.239.u
# CFIS.053.179.u
# CFIS.053.188.u
# CFIS.053.190.u
# CFIS.053.231.u
# CFIS.054.180.u
# CFIS.054.205.u
# CFIS.054.209.u
# CFIS.054.226.u
# CFIS.055.181.u
# CFIS.055.187.u
# CFIS.055.208.u
# CFIS.056.180.u
# CFIS.056.182.u
# CFIS.056.187.u
# CFIS.056.190.u
# CFIS.057.187.u
# CFIS.057.241.r
# CFIS.057.241.u
# CFIS.057.252.u
# CFIS.058.209.u
# CFIS.058.212.u
# CFIS.059.179.u
# CFIS.059.207.u
# CFIS.061.187.u
# CFIS.061.188.u
# CFIS.062.192.u
# CFIS.062.233.u
# CFIS.064.184.u
# CFIS.064.187.u
# CFIS.064.190.u
# CFIS.064.239.r
# CFIS.064.239.u
# CFIS.065.179.u
# CFIS.065.180.u
# CFIS.065.330.r
# CFIS.066.180.u
# CFIS.066.181.u
# CFIS.068.179.u
# CFIS.068.185.u
# CFIS.068.186.u
# CFIS.068.321.r
# CFIS.069.179.u
# CFIS.069.191.u
# CFIS.070.185.u
# CFIS.070.192.u
# CFIS.070.320.r
# CFIS.072.180.u
# CFIS.072.185.u
# CFIS.073.181.u
# CFIS.074.187.u
# CFIS.074.188.u
# CFIS.075.186.u
# CFIS.077.188.u
# CFIS.078.187.u
# CFIS.081.179.u
# CFIS.081.184.u
# CFIS.081.185.u
# CFIS.082.180.u
# CFIS.083.179.u
# CFIS.083.183.u
# CFIS.083.188.u
# CFIS.084.179.u
# CFIS.084.186.u
# CFIS.085.179.u
# CFIS.085.180.u
# CFIS.086.179.u
# CFIS.086.181.u
# CFIS.088.181.u
# CFIS.089.183.u
# CFIS.090.182.u
# CFIS.090.189.u
# CFIS.118.295.r
# CFIS.118.295.u
# CFIS.136.284.r
# CFIS.137.285.r
# CFIS.138.288.r
# CFIS.138.290.r
# CFIS.141.283.r
# CFIS.142.280.r
# CFIS.142.280.u
# CFIS.144.285.r
# CFIS.146.282.r
# CFIS.146.282.u
# CFIS.147.282.r
# CFIS.147.282.u
# CFIS.147.288.r
# CFIS.148.291.r
# CFIS.148.291.u
# CFIS.150.275.r
# CFIS.150.275.u
# CFIS.150.276.r
# CFIS.150.276.u
# CFIS.150.282.r
# CFIS.150.282.u
# CFIS.151.273.u
# CFIS.154.285.r
# CFIS.154.286.r
# CFIS.156.285.r
# CFIS.159.282.r
# CFIS.159.282.u
# CFIS.159.283.r
# CFIS.160.274.r
# CFIS.160.274.u
# CFIS.161.272.r
# CFIS.161.272.u
# CFIS.162.275.r
# CFIS.162.275.u
# CFIS.162.284.r
# CFIS.163.275.r
# CFIS.163.275.u
# CFIS.163.279.r
# CFIS.163.279.u
# CFIS.164.278.r
# CFIS.164.278.u
# CFIS.164.279.r
# CFIS.164.279.u
# CFIS.164.282.r
# CFIS.164.282.u
# CFIS.165.268.r
# CFIS.165.268.u
# CFIS.165.270.r
# CFIS.165.270.u
# CFIS.166.268.r
# CFIS.166.268.u
# CFIS.166.270.r
# CFIS.166.270.u
# CFIS.166.281.r
# CFIS.166.281.u
# CFIS.167.274.r
# CFIS.167.274.u
# CFIS.168.268.r
# CFIS.168.268.u
# CFIS.172.263.r
# CFIS.172.263.u
# CFIS.172.268.r
# CFIS.172.268.u
# CFIS.174.267.r
# CFIS.174.267.u
# CFIS.174.271.r
# CFIS.174.271.u
# CFIS.174.279.r
# CFIS.175.268.r
# CFIS.175.268.u
# CFIS.175.271.r
# CFIS.175.271.u
# CFIS.176.257.u
# CFIS.177.256.u
# CFIS.177.293.r
# CFIS.179.259.r
# CFIS.179.259.u
# CFIS.182.277.r
# CFIS.183.255.r
# CFIS.183.255.u
# CFIS.183.292.r
# CFIS.183.292.u
# CFIS.184.263.r
# CFIS.184.263.u
# CFIS.184.266.r
# CFIS.184.266.u
# CFIS.185.291.u
# CFIS.186.253.r
# CFIS.186.253.u
# CFIS.188.307.r
# CFIS.189.250.r
# CFIS.189.250.u
# CFIS.190.240.u
# CFIS.190.249.r
# CFIS.190.249.u
# CFIS.190.256.r
# CFIS.190.256.u
# CFIS.191.243.u
# CFIS.191.256.r
# CFIS.191.256.u
# CFIS.191.263.r
# CFIS.191.263.u
# CFIS.191.290.r
# CFIS.191.290.u
# CFIS.192.263.r
# CFIS.192.263.u
# CFIS.192.270.r
# CFIS.192.270.u
# CFIS.193.245.u
# CFIS.193.247.r
# CFIS.193.247.u
# CFIS.193.262.r
# CFIS.193.262.u
# CFIS.194.240.u
# CFIS.194.247.r
# CFIS.194.247.u
# CFIS.194.262.r
# CFIS.194.262.u
# CFIS.194.305.r
# CFIS.195.250.r
# CFIS.195.250.u
# CFIS.195.307.r
# CFIS.196.271.r
# CFIS.196.271.u
# CFIS.196.287.r
# CFIS.196.287.u
# CFIS.197.271.r
# CFIS.197.271.u
# CFIS.197.287.r
# CFIS.197.287.u
# CFIS.198.275.r
# CFIS.199.255.r
# CFIS.199.255.u
# CFIS.200.239.u
# CFIS.200.266.r
# CFIS.200.266.u
# CFIS.201.285.r
# CFIS.201.285.u
# CFIS.201.287.r
# CFIS.201.287.u
# CFIS.201.289.u
# CFIS.201.311.r
# CFIS.202.243.r
# CFIS.202.243.u
# CFIS.202.261.r
# CFIS.202.261.u
# CFIS.202.265.r
# CFIS.202.265.u
# CFIS.203.248.r
# CFIS.203.248.u
# CFIS.203.263.r
# CFIS.203.263.u
# CFIS.203.285.r
# CFIS.203.285.u
# CFIS.204.248.r
# CFIS.204.248.u
# CFIS.204.257.r
# CFIS.204.257.u
# CFIS.204.269.r
# CFIS.204.269.u
# CFIS.204.278.r
# CFIS.204.307.r
# CFIS.204.312.r
# CFIS.205.269.r
# CFIS.205.269.u
# CFIS.205.286.r
# CFIS.205.286.u
# CFIS.205.300.r
# CFIS.206.240.r
# CFIS.206.240.u
# CFIS.206.264.r
# CFIS.206.264.u
# CFIS.207.235.u
# CFIS.208.234.u
# CFIS.208.305.r
# CFIS.209.235.u
# CFIS.209.272.r
# CFIS.210.230.u
# CFIS.210.260.r
# CFIS.210.260.u
# CFIS.211.235.u
# CFIS.211.245.r
# CFIS.211.245.u
# CFIS.211.252.r
# CFIS.211.252.u
# CFIS.211.262.r
# CFIS.211.262.u
# CFIS.211.286.u
# CFIS.212.223.u
# CFIS.212.275.r
# CFIS.212.301.r
# CFIS.213.232.u
# CFIS.213.243.r
# CFIS.213.243.u
# CFIS.213.274.r
# CFIS.213.296.r
# CFIS.214.269.r
# CFIS.214.269.u
# CFIS.214.284.u
# CFIS.215.266.r
# CFIS.215.266.u
# CFIS.216.250.r
# CFIS.216.250.u
# CFIS.217.257.r
# CFIS.217.257.u
# CFIS.217.283.u
# CFIS.217.303.r
# CFIS.218.228.u
# CFIS.218.269.r
# CFIS.218.273.r
# CFIS.218.300.r
# CFIS.219.235.u
# CFIS.219.260.r
# CFIS.219.260.u
# CFIS.219.264.r
# CFIS.219.264.u
# CFIS.219.269.r
# CFIS.219.286.u
# CFIS.220.275.r
# CFIS.220.275.u
# CFIS.221.243.r
# CFIS.221.243.u
# CFIS.221.267.r
# CFIS.221.308.r
# CFIS.222.232.u
# CFIS.222.247.r
# CFIS.222.247.u
# CFIS.222.261.r
# CFIS.222.261.u
# CFIS.223.231.u
# CFIS.223.241.r
# CFIS.223.241.u
# CFIS.223.250.r
# CFIS.223.250.u
# CFIS.223.280.u
# CFIS.224.224.u
# CFIS.224.234.u
# CFIS.224.241.r
# CFIS.224.241.u
# CFIS.224.250.r
# CFIS.224.250.u
# CFIS.224.251.r
# CFIS.224.251.u
# CFIS.224.255.r
# CFIS.224.255.u
# CFIS.224.272.r
# CFIS.224.272.u
# CFIS.224.299.r
# CFIS.225.241.r
# CFIS.225.241.u
# CFIS.225.250.r
# CFIS.225.250.u
# CFIS.225.254.r
# CFIS.225.254.u
# CFIS.225.272.r
# CFIS.225.272.u
# CFIS.226.253.r
# CFIS.226.253.u
# CFIS.226.273.r
# CFIS.226.273.u
# CFIS.227.234.u
# CFIS.227.244.r
# CFIS.227.244.u
# CFIS.227.257.r
# CFIS.227.257.u
# CFIS.227.270.r
# CFIS.227.294.r
# CFIS.227.295.r
# CFIS.228.252.r
# CFIS.228.252.u
# CFIS.228.262.r
# CFIS.228.262.u
# CFIS.228.281.u
# CFIS.228.294.r
# CFIS.229.220.u
# CFIS.229.266.r
# CFIS.229.266.u
# CFIS.229.267.r
# CFIS.229.267.u
# CFIS.229.294.r
# CFIS.229.296.r
# CFIS.230.247.r
# CFIS.230.247.u
# CFIS.230.261.r
# CFIS.230.261.u
# CFIS.230.265.r
# CFIS.230.265.u
# CFIS.230.294.r
# CFIS.230.296.r
# CFIS.231.249.r
# CFIS.231.249.u
# CFIS.231.274.r
# CFIS.231.274.u
# CFIS.231.289.r
# CFIS.232.235.u
# CFIS.232.264.r
# CFIS.232.264.u
# CFIS.232.294.r
# CFIS.232.295.r
# CFIS.233.295.r
# CFIS.234.295.r
# CFIS.235.219.u
# CFIS.235.286.r
# CFIS.235.292.r
# CFIS.236.218.u
# CFIS.236.219.u
# CFIS.236.293.r
# CFIS.236.294.r
# CFIS.237.291.r
# CFIS.237.296.r
# CFIS.238.217.u
# CFIS.238.223.u
# CFIS.238.233.u
# CFIS.238.278.r
# CFIS.238.278.u
# CFIS.238.291.r
# CFIS.238.293.r
# CFIS.238.294.r
# CFIS.239.218.u
# CFIS.239.225.u
# CFIS.239.242.r
# CFIS.239.242.u
# CFIS.239.258.r
# CFIS.239.258.u
# CFIS.240.233.u
# CFIS.240.258.r
# CFIS.240.258.u
# CFIS.240.273.u
# CFIS.240.293.r
# CFIS.240.299.r
# CFIS.241.241.r
# CFIS.241.241.u
# CFIS.241.266.r
# CFIS.241.266.u
# CFIS.241.290.r
# CFIS.242.229.u
# CFIS.242.237.u
# CFIS.242.260.r
# CFIS.242.260.u
# CFIS.242.288.r
# CFIS.242.290.r
# CFIS.243.290.r
# CFIS.243.292.r
# CFIS.244.249.r
# CFIS.244.249.u
# CFIS.244.267.r
# CFIS.244.267.u
# CFIS.244.268.r
# CFIS.244.268.u
# CFIS.244.275.r
# CFIS.244.275.u
# CFIS.244.284.r
# CFIS.244.294.r
# CFIS.244.296.r
# CFIS.245.224.u
# CFIS.245.227.u
# CFIS.245.228.u
# CFIS.245.268.r
# CFIS.245.268.u
# CFIS.245.275.r
# CFIS.245.284.r
# CFIS.245.289.r
# CFIS.245.290.r
# CFIS.245.297.r
# CFIS.246.220.u
# CFIS.246.243.r
# CFIS.246.243.u
# CFIS.246.245.r
# CFIS.246.245.u
# CFIS.246.257.r
# CFIS.246.257.u
# CFIS.246.281.r
# CFIS.246.289.r
# CFIS.246.291.r
# CFIS.247.291.r
# CFIS.248.230.u
# CFIS.248.235.u
# CFIS.248.272.r
# CFIS.248.272.u
# CFIS.249.263.r
# CFIS.249.263.u
# CFIS.249.287.r
# CFIS.250.223.u
# CFIS.250.286.r
# CFIS.252.220.u
# CFIS.252.248.r
# CFIS.252.248.u
# CFIS.252.250.r
# CFIS.252.250.u
# CFIS.253.230.u
# CFIS.253.263.r
# CFIS.253.263.u
# CFIS.253.283.r
# CFIS.253.286.r
# CFIS.254.287.r
# CFIS.255.255.r
# CFIS.255.255.u
# CFIS.256.287.r
# CFIS.257.232.u
# CFIS.257.266.r
# CFIS.257.266.u
# CFIS.257.285.r
# CFIS.258.216.u
# CFIS.258.285.r
# CFIS.258.296.r
# CFIS.259.216.u
# CFIS.259.243.r
# CFIS.259.243.u
# CFIS.259.245.r
# CFIS.259.245.u
# CFIS.259.253.r
# CFIS.259.253.u
# CFIS.259.286.r
# CFIS.259.300.u
# CFIS.260.251.r
# CFIS.260.251.u
# CFIS.260.284.r
# CFIS.260.285.r
# CFIS.260.296.r
# CFIS.261.266.r
# CFIS.261.266.u
# CFIS.261.284.r
# CFIS.261.285.r
# CFIS.262.261.r
# CFIS.262.261.u
# CFIS.262.263.r
# CFIS.262.263.u
# CFIS.262.265.r
# CFIS.262.265.u
# CFIS.262.270.r
# CFIS.262.284.r
# CFIS.262.285.r
# CFIS.263.252.r
# CFIS.263.252.u
# CFIS.263.262.r
# CFIS.263.262.u
# CFIS.263.267.r
# CFIS.263.299.r
# CFIS.263.299.u
# CFIS.264.251.r
# CFIS.264.251.u
# CFIS.264.256.r
# CFIS.264.256.u
# CFIS.264.267.r
# CFIS.264.284.r
# CFIS.264.299.r
# CFIS.264.299.u
# CFIS.265.233.u
# CFIS.265.256.r
# CFIS.265.256.u
# CFIS.266.298.r
# CFIS.266.298.u
# CFIS.267.235.u
# CFIS.267.283.r
# CFIS.267.284.r
# CFIS.268.244.u
# CFIS.268.254.r
# CFIS.268.254.u
# CFIS.268.301.r
# CFIS.269.246.r
# CFIS.269.246.u
# CFIS.269.270.r
# CFIS.269.283.r
# CFIS.270.264.r
# CFIS.270.264.u
# CFIS.270.283.r
# CFIS.270.293.r
# CFIS.271.236.u
# CFIS.271.276.r
# CFIS.271.293.r
# CFIS.272.253.r
# CFIS.272.253.u
# CFIS.272.254.r
# CFIS.272.254.u
# CFIS.272.256.r
# CFIS.272.256.u
# CFIS.272.264.r
# CFIS.272.264.u
# CFIS.272.283.r
# CFIS.273.263.r
# CFIS.273.263.u
# CFIS.273.273.r
# CFIS.274.262.r
# CFIS.274.262.u
# CFIS.275.270.r
# CFIS.275.272.r
# CFIS.275.300.r
# CFIS.276.239.u
# CFIS.276.241.r
# CFIS.276.241.u
# CFIS.276.242.r
# CFIS.276.242.u
# CFIS.276.243.r
# CFIS.276.243.u
# CFIS.276.255.r
# CFIS.276.255.u
# CFIS.277.286.r
# CFIS.278.248.r
# CFIS.278.248.u
# CFIS.278.282.r
# CFIS.278.284.r
# CFIS.279.243.r
# CFIS.279.243.u
# CFIS.280.252.r
# CFIS.280.252.u
# CFIS.280.281.r
# CFIS.282.233.u
# CFIS.283.280.r
# CFIS.284.248.r
# CFIS.284.248.u
# CFIS.284.253.r
# CFIS.284.253.u
# CFIS.284.289.r
# CFIS.286.236.u
# CFIS.287.297.r
# CFIS.288.278.r
# CFIS.289.294.r
# CFIS.289.294.u
# CFIS.290.235.u
# CFIS.290.290.r
# CFIS.292.256.r
# CFIS.292.256.u
# CFIS.293.242.r
# CFIS.293.242.u
# CFIS.293.244.r
# CFIS.293.244.u
# CFIS.293.263.r
# CFIS.293.263.u
# CFIS.293.272.r
# CFIS.294.238.r
# CFIS.294.238.u
# CFIS.294.252.r
# CFIS.294.252.u
# CFIS.294.286.r
# CFIS.295.237.u
# CFIS.295.240.r
# CFIS.295.240.u
# CFIS.295.277.r
# CFIS.295.280.r
# CFIS.296.228.u
# CFIS.296.236.u
# CFIS.296.246.r
# CFIS.296.246.u
# CFIS.296.253.r
# CFIS.296.253.u
# CFIS.296.277.r
# CFIS.297.255.r
# CFIS.297.255.u
# CFIS.298.269.r
# CFIS.298.274.r
# CFIS.298.276.r
# CFIS.298.295.r
# CFIS.298.295.u
# CFIS.299.234.u
# CFIS.299.246.r
# CFIS.299.246.u
# CFIS.299.270.r
# CFIS.299.295.r
# CFIS.299.295.u
# CFIS.300.251.r
# CFIS.300.251.u
# CFIS.300.280.r
# CFIS.301.265.r
# CFIS.302.222.u
# CFIS.302.226.u
# CFIS.303.218.u
# CFIS.303.227.u
# CFIS.303.233.u
# CFIS.303.278.r
# CFIS.304.233.u
# CFIS.304.241.r
# CFIS.304.241.u
# CFIS.304.255.r
# CFIS.304.255.u
# CFIS.305.240.r
# CFIS.305.240.u
# CFIS.306.220.u
# CFIS.306.270.r
# CFIS.307.228.u
# CFIS.308.228.u
# CFIS.308.231.u
# CFIS.308.239.r
# CFIS.308.239.u
# CFIS.308.253.r
# CFIS.308.253.u
# CFIS.310.221.u
# CFIS.310.238.r
# CFIS.310.238.u
# CFIS.310.261.r
# CFIS.310.261.u
# CFIS.310.273.r
# CFIS.311.259.r
# CFIS.311.259.u
# CFIS.313.223.u
# CFIS.314.228.u
# CFIS.314.240.r
# CFIS.314.240.u
# CFIS.314.277.r
# CFIS.314.290.r
# CFIS.314.290.u
# CFIS.315.227.u
# CFIS.315.243.r
# CFIS.315.243.u
# CFIS.315.266.r
# CFIS.316.256.u
# CFIS.317.260.u
# CFIS.318.232.u
# CFIS.318.279.r
# CFIS.318.279.u
# CFIS.319.276.r
# CFIS.319.290.r
# CFIS.319.290.u
# CFIS.320.218.u
# CFIS.321.237.u
# CFIS.321.257.u
# CFIS.322.226.u
# CFIS.322.269.r
# CFIS.323.224.u
# CFIS.323.235.u
# CFIS.323.289.r
# CFIS.323.289.u
# CFIS.324.225.u
# CFIS.324.278.r
# CFIS.324.278.u
# CFIS.325.234.u
# CFIS.325.235.u
# CFIS.325.243.r
# CFIS.325.243.u
# CFIS.325.256.u
# CFIS.325.257.u
# CFIS.326.219.u
# CFIS.326.224.u
# CFIS.326.253.u
# CFIS.326.276.r
# CFIS.326.276.u
# CFIS.327.218.u
# CFIS.327.231.u
# CFIS.328.225.u
# CFIS.328.262.r
# CFIS.328.262.u
# CFIS.328.268.r
# CFIS.328.268.u
# CFIS.328.279.r
# CFIS.328.279.u
# CFIS.329.253.u
# CFIS.329.270.r
# CFIS.330.226.u
# CFIS.330.236.u
# CFIS.330.260.r
# CFIS.330.260.u
# CFIS.331.219.u
# CFIS.331.233.u
# CFIS.331.257.u
# CFIS.332.270.r
# CFIS.332.272.r
# CFIS.332.272.u
# CFIS.333.223.u
# CFIS.333.227.u
# CFIS.333.268.r
# CFIS.333.268.u
# CFIS.333.270.r
# CFIS.333.270.u
# CFIS.335.234.u
# CFIS.335.252.u
# CFIS.335.269.r
# CFIS.336.235.u
# CFIS.336.239.r
# CFIS.336.239.u
# CFIS.336.264.r
# CFIS.336.264.u
# CFIS.337.219.u
# CFIS.337.236.u
# CFIS.337.241.r
# CFIS.337.241.u
# CFIS.337.271.r
# CFIS.337.271.u
# CFIS.338.235.u
# CFIS.338.237.u
# CFIS.339.218.u
# CFIS.339.228.u
# CFIS.339.233.u
# CFIS.339.247.u
# CFIS.339.263.r
# CFIS.339.263.u
# CFIS.340.231.u
# CFIS.340.242.r
# CFIS.340.242.u
# CFIS.340.260.r
# CFIS.340.260.u
# CFIS.340.269.r
# CFIS.340.269.u
# CFIS.340.274.r
# CFIS.340.274.u
# CFIS.341.233.u
# CFIS.341.247.u
# CFIS.341.265.r
# CFIS.341.265.u
# CFIS.341.268.r
# CFIS.341.268.u
# CFIS.341.284.r
# CFIS.341.284.u
# CFIS.342.231.u
# CFIS.342.241.r
# CFIS.342.241.u
# CFIS.342.243.r
# CFIS.342.243.u
# CFIS.342.249.u
# CFIS.342.264.r
# CFIS.342.264.u
# CFIS.342.269.r
# CFIS.342.269.u
# CFIS.342.271.r
# CFIS.342.271.u
# CFIS.344.224.u
# CFIS.344.231.u
# CFIS.344.269.r
# CFIS.344.269.u
# CFIS.345.236.u
# CFIS.345.243.r
# CFIS.345.243.u
# CFIS.345.267.r
# CFIS.346.183.u
# CFIS.346.224.u
# CFIS.346.231.u
# CFIS.346.246.u
# CFIS.346.267.r
# CFIS.346.268.r
# CFIS.346.268.u
# CFIS.347.182.u
# CFIS.347.184.u
# CFIS.347.185.u
# CFIS.347.271.r
# CFIS.347.271.u
# CFIS.347.272.r
# CFIS.347.272.u
# CFIS.348.180.u
# CFIS.348.181.u
# CFIS.348.182.u
# CFIS.348.183.u
# CFIS.348.184.u
# CFIS.348.185.u
# CFIS.348.187.u
# CFIS.348.218.u
# CFIS.348.238.u
# CFIS.348.267.r
# CFIS.349.183.u
# CFIS.349.184.u
# CFIS.349.185.u
# CFIS.349.186.u
# CFIS.349.232.u
# CFIS.349.255.u
# CFIS.349.267.r
# CFIS.350.180.u
# CFIS.350.181.u
# CFIS.350.182.u
# CFIS.350.184.u
# CFIS.350.185.u
# CFIS.350.234.u
# CFIS.350.267.r
# CFIS.350.268.r
# CFIS.350.268.u
# CFIS.350.273.r
# CFIS.350.273.u
# CFIS.351.181.u
# CFIS.351.182.u
# CFIS.351.219.u
# CFIS.351.233.u
# CFIS.351.245.r
# CFIS.351.245.u
# CFIS.351.268.r
# CFIS.351.268.u
# CFIS.352.180.u
# CFIS.352.181.u
# CFIS.352.239.r
# CFIS.352.239.u
# CFIS.352.253.u
# CFIS.352.265.r
# CFIS.352.268.r
# CFIS.352.268.u
# CFIS.352.269.r
# CFIS.352.269.u
# CFIS.353.180.u
# CFIS.353.181.u
# CFIS.353.182.u
# CFIS.353.257.u
# CFIS.353.258.r
# CFIS.353.258.u
# CFIS.354.181.u
# CFIS.354.183.u
# CFIS.354.243.r
# CFIS.354.243.u
# CFIS.354.244.r
# CFIS.354.244.u
# CFIS.354.254.u
# CFIS.355.180.u
# CFIS.355.183.u
# CFIS.355.184.u
# CFIS.355.223.u
# CFIS.355.250.r
# CFIS.355.250.u
# CFIS.355.264.r
# CFIS.355.267.r
# CFIS.356.181.u
# CFIS.356.182.u
# CFIS.356.183.u
# CFIS.356.257.u
# CFIS.356.267.r
# CFIS.356.268.r
# CFIS.356.268.u
# CFIS.357.181.u
# CFIS.357.183.u
# CFIS.357.184.u
# CFIS.358.180.u
# CFIS.358.182.u
# CFIS.358.183.u
# CFIS.358.185.u
# CFIS.358.225.u
# CFIS.358.243.r
# CFIS.358.243.u
# CFIS.358.250.u
# CFIS.358.261.r
# CFIS.358.266.r
# CFIS.358.277.r
# CFIS.358.277.u
# CFIS.359.182.u
# CFIS.359.183.u
# CFIS.359.184.u
# CFIS.359.186.u
# CFIS.359.250.u
# CFIS.359.264.r
# CFIS.359.265.r
# CFIS.359.267.r
# CFIS.360.180.u
# CFIS.360.182.u
# CFIS.360.185.u
# CFIS.360.237.u
# CFIS.360.265.r
# CFIS.361.180.u
# CFIS.361.182.u
# CFIS.361.183.u
# CFIS.361.186.u
# CFIS.361.226.u
# CFIS.361.249.u
# CFIS.362.180.u
# CFIS.362.183.u
# CFIS.362.218.u
# CFIS.362.226.u
# CFIS.363.180.u
# CFIS.363.181.u
# CFIS.363.182.u
# CFIS.363.183.u
# CFIS.363.184.u
# CFIS.363.185.u
# CFIS.363.237.u
# CFIS.364.182.u
# CFIS.365.180.u
# CFIS.365.182.u
# CFIS.365.183.u
# CFIS.365.184.u
# CFIS.365.244.r
# CFIS.365.244.u
# CFIS.365.250.u
# CFIS.365.270.r
# CFIS.365.270.u
# CFIS.366.182.u
# CFIS.366.183.u
# CFIS.366.184.u
# CFIS.366.218.u
# CFIS.367.181.u
# CFIS.367.182.u
# CFIS.367.184.u
# CFIS.367.185.u
# CFIS.368.180.u
# CFIS.368.181.u
# CFIS.368.183.u
# CFIS.368.221.u
# CFIS.368.231.u
# CFIS.368.247.u
# CFIS.369.180.u
# CFIS.369.181.u
# CFIS.369.220.u
# CFIS.369.241.r
# CFIS.369.241.u
# CFIS.369.246.u
# CFIS.370.181.u
# CFIS.370.182.u
# CFIS.370.185.u
# CFIS.370.266.r
# CFIS.370.266.u
# CFIS.371.181.u
# CFIS.371.182.u
# CFIS.371.183.u
# CFIS.371.184.u
# CFIS.371.185.u
# CFIS.371.240.r
# CFIS.371.240.u
# CFIS.372.184.u
# CFIS.372.239.r
# CFIS.372.239.u
# CFIS.372.247.u
# CFIS.373.180.u
# CFIS.373.259.r
# CFIS.373.259.u
# CFIS.374.180.u
# CFIS.374.184.u
# CFIS.374.185.u
# CFIS.374.225.u
# CFIS.374.267.r
# CFIS.374.267.u
# CFIS.375.180.u
# CFIS.375.182.u
# CFIS.375.243.u
# CFIS.375.252.r
# CFIS.375.252.u
# CFIS.376.181.u
# CFIS.376.253.r
# CFIS.376.253.u
# CFIS.377.180.u
# CFIS.377.181.u
# CFIS.378.182.u
# CFIS.378.272.r
# CFIS.378.272.u
# CFIS.379.180.u
# CFIS.379.181.u
# CFIS.379.259.r
# CFIS.379.259.u
# CFIS.380.225.u
# CFIS.380.255.r
# CFIS.380.255.u
# CFIS.381.180.u
# CFIS.381.181.u
# CFIS.381.245.u
# CFIS.382.182.u
# CFIS.382.236.u
# CFIS.382.239.u
# CFIS.382.241.u
# CFIS.383.223.u
# CFIS.383.237.u
# CFIS.383.263.r
# CFIS.383.263.u
# CFIS.386.247.u
# CFIS.386.248.r
# CFIS.386.248.u
# CFIS.387.229.u
# CFIS.387.246.u
# CFIS.387.259.r
# CFIS.387.259.u
# CFIS.388.219.u
# CFIS.388.241.u
# CFIS.388.250.r
# CFIS.388.250.u
# CFIS.389.230.u
# CFIS.389.242.u
# CFIS.389.267.r
# CFIS.389.267.u
# CFIS.390.231.u
# CFIS.392.226.u
# CFIS.392.230.u
# CFIS.392.250.r
# CFIS.392.250.u
# CFIS.393.240.u
# CFIS.393.245.r
# CFIS.393.245.u
# CFIS.394.219.u
# CFIS.395.218.u
# CFIS.395.228.u
# CFIS.396.223.u
# CFIS.396.245.r
# CFIS.396.245.u
# CFIS.397.228.u
# CFIS.398.222.u
# CFIS.398.226.u
# CFIS.398.230.u
# CFIS.398.242.r
# CFIS.398.242.u
# CFIS.398.248.r
# CFIS.398.248.u
# CFIS.399.223.u
# CFIS.399.236.u
# CFIS.400.226.u
# CFIS.401.264.r
# CFIS.401.264.u
# CFIS.402.228.u
# CFIS.402.238.u
# CFIS.402.247.r
# CFIS.402.247.u
# CFIS.403.219.u
# CFIS.403.223.u
# CFIS.403.238.r
# CFIS.403.238.u
# CFIS.403.244.r
# CFIS.403.244.u
# CFIS.403.257.r
# CFIS.403.257.u
# CFIS.404.220.u
# CFIS.405.240.r
# CFIS.405.240.u
# CFIS.406.250.r
# CFIS.406.250.u
# CFIS.407.227.u
# CFIS.407.242.r
# CFIS.407.242.u
# CFIS.407.244.r
# CFIS.407.244.u
# CFIS.408.235.u
# CFIS.408.260.r
# CFIS.408.260.u
# CFIS.409.222.u
# CFIS.411.247.r
# CFIS.411.247.u
# CFIS.412.223.u
# CFIS.416.226.u
# CFIS.416.231.u
# CFIS.417.236.u
# CFIS.417.250.r
# CFIS.417.250.u
# CFIS.418.229.u
# CFIS.418.236.u
# CFIS.424.232.u
# CFIS.424.243.r
# CFIS.424.243.u
# CFIS.425.234.u
# CFIS.425.243.r
# CFIS.425.243.u
# CFIS.426.221.u
# CFIS.426.222.u
# CFIS.427.233.u
# CFIS.427.234.u
# CFIS.431.243.r
# CFIS.431.243.u
# CFIS.431.244.r
# CFIS.431.244.u
# CFIS.432.228.u
# CFIS.433.242.r
# CFIS.433.242.u
# CFIS.433.248.r
# CFIS.433.248.u
# CFIS.433.253.r
# CFIS.433.253.u
# CFIS.434.242.r
# CFIS.434.242.u
# CFIS.435.248.r
# CFIS.435.248.u
# CFIS.436.229.u
# CFIS.437.244.r
# CFIS.437.252.r
# CFIS.437.252.u
# CFIS.440.216.u
# CFIS.440.222.u
# CFIS.440.224.u
# CFIS.441.224.u
# CFIS.442.235.u
# CFIS.442.244.r
# CFIS.442.244.u
# CFIS.443.244.r
# CFIS.443.244.u
# CFIS.443.248.r
# CFIS.443.248.u
# CFIS.443.250.r
# CFIS.443.250.u
# CFIS.446.225.u
# CFIS.447.223.u
# CFIS.447.236.u
# CFIS.448.216.u
# CFIS.449.225.u
# CFIS.449.236.u
# CFIS.449.237.u
# CFIS.449.238.r
# CFIS.449.238.u
# CFIS.450.233.u
# CFIS.451.221.u
# CFIS.451.224.u
# CFIS.451.234.u
# CFIS.452.239.r
# CFIS.452.239.u
# CFIS.455.225.u
# CFIS.455.237.u
# CFIS.457.223.u
# CFIS.458.221.u
# CFIS.458.235.u
# CFIS.460.216.u
# CFIS.461.232.u
# CFIS.462.232.u
# CFIS.463.226.u
# CFIS.464.230.u
# CFIS.466.234.u
# CFIS.466.235.u
# CFIS.467.223.u
# CFIS.467.227.u
# CFIS.469.218.u
# CFIS.471.233.u
# CFIS.471.234.u
# CFIS.472.219.u
# CFIS.472.227.u
# CFIS.472.238.u
# CFIS.473.218.u
# CFIS.473.229.u
# CFIS.474.228.u
# CFIS.475.234.u
# CFIS.477.228.u
# CFIS.490.227.u
# CFIS.507.196.u
# CFIS.507.197.u
# CFIS.553.254.u
# CFIS.571.254.r
# CFIS.571.254.u
# CFIS.577.245.u
# CFIS.586.240.u
# CFIS.593.236.u
# CFIS.593.243.r
# CFIS.593.243.u
# CFIS.594.230.u
# CFIS.594.248.r
# CFIS.594.248.u
# CFIS.595.241.r
# CFIS.595.241.u
# CFIS.596.228.u
# CFIS.596.241.r
# CFIS.596.241.u
# CFIS.600.221.u
# CFIS.600.226.u
# CFIS.600.235.u
# CFIS.600.241.r
# CFIS.600.241.u
# CFIS.602.233.u
# CFIS.602.236.u
# CFIS.602.246.g
# CFIS.602.246.i
# CFIS.602.246.r
# CFIS.602.246.u
# CFIS.603.227.u
# CFIS.606.225.u
# CFIS.606.227.u
# CFIS.606.234.u
# CFIS.607.238.r
# CFIS.607.238.u
# CFIS.611.237.u
# CFIS.613.220.u
# CFIS.614.232.u
# CFIS.615.235.u
# CFIS.615.240.r
# CFIS.615.240.u
# CFIS.625.222.u
# CFIS.627.193.u
# CFIS.628.185.u
# CFIS.628.189.u
# CFIS.628.200.u
# CFIS.628.224.u
# CFIS.628.225.u
# CFIS.630.185.u
# CFIS.630.213.u
# CFIS.631.188.u
# CFIS.631.220.u
# CFIS.632.190.u
# CFIS.633.188.u
# CFIS.633.200.u
# CFIS.634.227.u
# CFIS.635.190.u
# CFIS.635.191.u
# CFIS.635.214.u
# CFIS.636.191.u
# CFIS.636.194.u
# CFIS.636.208.u
# CFIS.638.180.u
# CFIS.638.185.u
# CFIS.638.196.u
# CFIS.638.232.u
# CFIS.639.179.u
# CFIS.639.196.u
# CFIS.640.180.u
# CFIS.640.188.u
# CFIS.640.224.u
# CFIS.641.184.u
# CFIS.641.188.u
# CFIS.641.221.u
# CFIS.642.204.u
# CFIS.643.180.u
# CFIS.643.220.u
# CFIS.643.234.u
# CFIS.644.204.u
# CFIS.645.231.u
# CFIS.647.216.u
# CFIS.649.211.u
# CFIS.649.228.u
# CFIS.650.180.u
# CFIS.650.201.u
# CFIS.650.210.u
# CFIS.650.216.u
# CFIS.650.225.u
# CFIS.651.180.u
# CFIS.651.210.u
# CFIS.652.189.u
# CFIS.652.190.u
# CFIS.654.220.u
# CFIS.655.179.u
# CFIS.655.193.u
# CFIS.655.194.u
# CFIS.655.211.u
# CFIS.656.194.u
# CFIS.657.181.u
# CFIS.657.193.u
# CFIS.658.186.u
# CFIS.658.192.u
# CFIS.658.198.u
# CFIS.659.188.u
# CFIS.659.201.u
# CFIS.659.204.u
# CFIS.659.214.u
# CFIS.659.221.u
# CFIS.660.182.u
# CFIS.660.183.u
# CFIS.660.184.u
# CFIS.661.182.u
# CFIS.661.184.u
# CFIS.661.190.u
# CFIS.661.193.u
# CFIS.661.198.u
# CFIS.661.219.u
# CFIS.662.184.u
# CFIS.662.188.u
# CFIS.662.190.u
# CFIS.663.180.u
# CFIS.663.182.u
# CFIS.663.226.u
# CFIS.664.179.u
# CFIS.664.224.u
# CFIS.665.181.u
# CFIS.665.195.u
# CFIS.665.217.u
# CFIS.666.181.u
# CFIS.666.185.u
# CFIS.666.189.u
# CFIS.666.223.u
# CFIS.667.179.u
# CFIS.667.180.u
# CFIS.667.182.u
# CFIS.668.187.u
# CFIS.669.179.u
# CFIS.669.180.u
# CFIS.669.181.u
# CFIS.669.183.u
# CFIS.670.179.u
# CFIS.670.182.u
# CFIS.670.183.u
# CFIS.670.209.u
# CFIS.670.221.u
# CFIS.670.223.u
# CFIS.671.180.u
# CFIS.671.182.u
# CFIS.671.183.u
# CFIS.671.184.u
# CFIS.672.195.u
# CFIS.673.181.u
# CFIS.673.182.u
# CFIS.673.216.u
# CFIS.674.183.u
# CFIS.675.183.u
# CFIS.675.204.u
# CFIS.675.210.u
# CFIS.676.183.u
# CFIS.676.186.u
# CFIS.676.209.u
# CFIS.677.183.u
# CFIS.677.184.u
# CFIS.679.182.u
# CFIS.679.187.u
# CFIS.680.180.u
# CFIS.680.182.u
# CFIS.680.185.u
# CFIS.680.186.u
# CFIS.680.207.u
# CFIS.681.180.u
# CFIS.681.216.u
# CFIS.682.206.u
# CFIS.683.181.u
# CFIS.683.198.u
# CFIS.683.204.u
# CFIS.684.184.u
# CFIS.684.204.u
# CFIS.685.181.u
# CFIS.685.182.u
# CFIS.685.204.u
# CFIS.685.207.u
# CFIS.685.212.u
# CFIS.686.179.u
# CFIS.686.188.u
# CFIS.687.190.u
# CFIS.689.195.u
# CFIS.689.202.u
# CFIS.690.181.u
# CFIS.691.187.u
# CFIS.692.180.u
# CFIS.692.181.u
# CFIS.692.191.u
# CFIS.692.208.u
# CFIS.694.190.u
# CFIS.694.203.u
# CFIS.696.200.u
# CFIS.697.180.u
# CFIS.698.184.u
# CFIS.698.191.u
# CFIS.700.179.u
# CFIS.700.195.u
# CFIS.704.180.u
# CFIS.704.198.u
# CFIS.705.192.u
# CFIS.706.180.u
# CFIS.706.185.u
# CFIS.706.190.u
# CFIS.708.181.u
# CFIS.709.196.u
# CFIS.711.180.u
# CFIS.712.179.u
# CFIS.714.180.u
# CFIS.714.184.u
# CFIS.715.190.u
# CFIS.715.192.u
# CFIS.716.182.u
# CFIS.716.192.u
# CFIS.718.185.u
# CFIS.719.183.u
# CFIS.719.184.u
# CFIS.719.187.u
# PS1.172.295.g
# PS1.172.295.i
# PS1.172.295.r
# PS1.172.295.z
# PS1.177.293.g
# PS1.177.293.i
# PS1.177.293.r
# PS1.177.293.z
# PS1.177.295.g
# PS1.177.295.i
# PS1.177.295.r
# PS1.177.295.z
# PS1.243.290.g
# PS1.243.290.i
# PS1.243.290.r
# PS1.245.289.g
# PS1.245.289.i
# PS1.245.289.r
# PS1.245.290.g
# PS1.245.290.i
# PS1.245.290.r
# PS1.246.289.g
# PS1.246.289.i
# PS1.246.289.r
# PS1.246.289.z
# PS1.253.286.g
# PS1.254.287.g
# PS1.254.287.i
# PS1.254.287.r
# PS1.254.287.z
# PS1.256.287.g
# PS1.256.287.i
# PS1.256.287.r
# PS1.256.287.z
# PS1.257.285.g
# PS1.257.285.i
# PS1.257.285.r
# PS1.257.285.z
# PS1.258.285.g
# PS1.258.285.i
# PS1.258.285.r
# PS1.258.285.z
# PS1.259.286.g
# PS1.259.286.i
# PS1.259.286.r
# PS1.259.286.z
# PS1.260.284.g
# PS1.260.284.i
# PS1.260.284.r
# PS1.260.284.z
# PS1.260.285.g
# PS1.260.285.i
# PS1.260.285.r
# PS1.260.285.z
# PS1.261.284.g
# PS1.261.284.i
# PS1.261.284.r
# PS1.261.284.z
# PS1.261.285.g
# PS1.261.285.i
# PS1.261.285.r
# PS1.261.285.z
# PS1.262.284.g
# PS1.262.284.i
# PS1.262.284.r
# PS1.262.284.z
# PS1.262.285.g
# PS1.262.285.i
# PS1.262.285.r
# PS1.262.285.z
# PS1.264.284.g
# PS1.264.284.i
# PS1.264.284.r
# PS1.264.284.z
# PS1.267.283.g
# PS1.267.283.i
# PS1.267.283.r
# PS1.267.283.z
# PS1.270.293.g
# PS1.270.293.i
# PS1.270.293.r
# PS1.270.293.z
# PS1.284.289.g
# PS1.284.289.i
# PS1.284.289.r
# PS1.284.289.z

# %%
len(tile_list)
# Out:
# 1636

# %%
label_subdirs = ["stronglensdb_confirmed_unige/", "stronglensdb_candidates_unige/", "canameras2020/",
                 "huang2020a_grade_A/", "huang2020a_grade_B/", "huang2020a_grade_C/", 
                 "huang2020b_grade_A/", "huang2020b_grade_B/", "huang2020b_grade_C/"]
filters = ["CFIS u/", "PS1 g/", "CFIS r/", "PS1 i/", "PS1 z/"]
filter_dict = {k:v for v,k in enumerate(filters)}

# %%
cd '/scratch/anahoban/stronglens/Code/Batch Loading/Currently used'
# Out:
# /scratch/anahoban/stronglens/Code/Batch Loading/Currently used

# %%
ls
# Out:
#  AnaTests.ipynb                     func_job2.py
# 'Create Filtered Cutouts.ipynb'     functions.py
# 'Lens Binary Classifier.ipynb'      job3.py
# 'Multi-Channel Autoencoder.ipynb'   job8-unbalanced_tiles-5039881.out
#  New_fcts.ipynb                     job_outputs/
# 'Plot Labelled Cutouts.ipynb'       job_scripts/
#  Twobands_tests.ipynb               labels/
#  __pycache__/                       norm_tests.ipynb
#  analysis_cutouts.ipynb             script_cat.sh
#  create_cutouts.py                  script_job3.sh
#  create_mastercat.py                slurm-5046791.out
#  create_models.py                   wandb/
#  func_job1.py

# %%
for label_subdir in label_subdirs:
    for f in filters:
        nlabels = 0
        subdir = './' + label_dir + label_subdir + f
        for t in os.listdir(subdir):
            if t == ".ipynb_checkpoints":
                nlabels += 0
            else:
                df = pd.read_csv(subdir + t)
                nlabels += len(df)
        print("Number of labels in {}: {}".format(subdir, nlabels))
# Out:
# Number of labels in ./labels/stronglensdb_confirmed_unige/CFIS u/: 199
# Number of labels in ./labels/stronglensdb_confirmed_unige/PS1 g/: 29
# Number of labels in ./labels/stronglensdb_confirmed_unige/CFIS r/: 182
# Number of labels in ./labels/stronglensdb_confirmed_unige/PS1 i/: 28
# Number of labels in ./labels/stronglensdb_confirmed_unige/PS1 z/: 23
# Number of labels in ./labels/stronglensdb_candidates_unige/CFIS u/: 416
# Number of labels in ./labels/stronglensdb_candidates_unige/PS1 g/: 9
# Number of labels in ./labels/stronglensdb_candidates_unige/CFIS r/: 148
# Number of labels in ./labels/stronglensdb_candidates_unige/PS1 i/: 9
# Number of labels in ./labels/stronglensdb_candidates_unige/PS1 z/: 9
# Number of labels in ./labels/canameras2020/CFIS u/: 129
# Number of labels in ./labels/canameras2020/PS1 g/: 1
# Number of labels in ./labels/canameras2020/CFIS r/: 49
# Number of labels in ./labels/canameras2020/PS1 i/: 1
# Number of labels in ./labels/canameras2020/PS1 z/: 1
# Number of labels in ./labels/huang2020a_grade_A/CFIS u/: 17
# Number of labels in ./labels/huang2020a_grade_A/PS1 g/: 0
# Number of labels in ./labels/huang2020a_grade_A/CFIS r/: 1
# Number of labels in ./labels/huang2020a_grade_A/PS1 i/: 0
# Number of labels in ./labels/huang2020a_grade_A/PS1 z/: 0
# Number of labels in ./labels/huang2020a_grade_B/CFIS u/: 35
# Number of labels in ./labels/huang2020a_grade_B/PS1 g/: 0
# Number of labels in ./labels/huang2020a_grade_B/CFIS r/: 2
# Number of labels in ./labels/huang2020a_grade_B/PS1 i/: 0
# Number of labels in ./labels/huang2020a_grade_B/PS1 z/: 0
# Number of labels in ./labels/huang2020a_grade_C/CFIS u/: 44
# Number of labels in ./labels/huang2020a_grade_C/PS1 g/: 0
# Number of labels in ./labels/huang2020a_grade_C/CFIS r/: 0
# Number of labels in ./labels/huang2020a_grade_C/PS1 i/: 0
# Number of labels in ./labels/huang2020a_grade_C/PS1 z/: 0
# Number of labels in ./labels/huang2020b_grade_A/CFIS u/: 63
# Number of labels in ./labels/huang2020b_grade_A/PS1 g/: 0
# Number of labels in ./labels/huang2020b_grade_A/CFIS r/: 22
# Number of labels in ./labels/huang2020b_grade_A/PS1 i/: 0
# Number of labels in ./labels/huang2020b_grade_A/PS1 z/: 0
# Number of labels in ./labels/huang2020b_grade_B/CFIS u/: 53
# Number of labels in ./labels/huang2020b_grade_B/PS1 g/: 1
# Number of labels in ./labels/huang2020b_grade_B/CFIS r/: 28
# Number of labels in ./labels/huang2020b_grade_B/PS1 i/: 1
# Number of labels in ./labels/huang2020b_grade_B/PS1 z/: 1
# Number of labels in ./labels/huang2020b_grade_C/CFIS u/: 258
# Number of labels in ./labels/huang2020b_grade_C/PS1 g/: 2
# Number of labels in ./labels/huang2020b_grade_C/CFIS r/: 92
# Number of labels in ./labels/huang2020b_grade_C/PS1 i/: 2
# Number of labels in ./labels/huang2020b_grade_C/PS1 z/: 2

# %%
# !ls labels/stronglensdb_confirmed_unige/CFIS\ u
# Out:
# 004.180_labels.csv  210.230_labels.csv	326.219_labels.csv  382.241_labels.csv
# 009.213_labels.csv  211.252_labels.csv	326.253_labels.csv  386.247_labels.csv
# 013.214_labels.csv  214.269_labels.csv	327.218_labels.csv  386.248_labels.csv
# 013.231_labels.csv  216.250_labels.csv	327.231_labels.csv  392.250_labels.csv
# 014.193_labels.csv  217.257_labels.csv	328.225_labels.csv  393.245_labels.csv
# 018.198_labels.csv  219.264_labels.csv	328.262_labels.csv  395.228_labels.csv
# 022.182_labels.csv  222.232_labels.csv	329.253_labels.csv  398.226_labels.csv
# 033.183_labels.csv  222.247_labels.csv	330.260_labels.csv  403.238_labels.csv
# 033.184_labels.csv  223.231_labels.csv	333.268_labels.csv  403.257_labels.csv
# 033.219_labels.csv  224.234_labels.csv	335.252_labels.csv  406.250_labels.csv
# 034.210_labels.csv  226.273_labels.csv	336.239_labels.csv  407.242_labels.csv
# 036.186_labels.csv  228.262_labels.csv	337.219_labels.csv  417.236_labels.csv
# 042.188_labels.csv  229.220_labels.csv	337.271_labels.csv  424.243_labels.csv
# 050.212_labels.csv  230.261_labels.csv	339.247_labels.csv  442.244_labels.csv
# 051.245_labels.csv  230.265_labels.csv	340.274_labels.csv  447.223_labels.csv
# 056.182_labels.csv  231.274_labels.csv	342.243_labels.csv  448.216_labels.csv
# 057.252_labels.csv  238.217_labels.csv	342.271_labels.csv  450.233_labels.csv
# 086.181_labels.csv  238.278_labels.csv	345.236_labels.csv  452.239_labels.csv
# 147.282_labels.csv  239.258_labels.csv	346.224_labels.csv  464.230_labels.csv
# 162.275_labels.csv  240.258_labels.csv	346.246_labels.csv  469.218_labels.csv
# 163.275_labels.csv  244.275_labels.csv	347.271_labels.csv  472.227_labels.csv
# 164.278_labels.csv  248.235_labels.csv	348.187_labels.csv  553.254_labels.csv
# 164.282_labels.csv  248.272_labels.csv	349.186_labels.csv  638.185_labels.csv
# 165.270_labels.csv  252.220_labels.csv	351.245_labels.csv  640.188_labels.csv
# 166.281_labels.csv  253.263_labels.csv	352.253_labels.csv  641.188_labels.csv
# 167.274_labels.csv  259.300_labels.csv	352.268_labels.csv  644.204_labels.csv
# 168.268_labels.csv  260.251_labels.csv	353.180_labels.csv  651.180_labels.csv
# 175.268_labels.csv  261.266_labels.csv	355.250_labels.csv  659.188_labels.csv
# 175.271_labels.csv  263.299_labels.csv	356.182_labels.csv  659.204_labels.csv
# 179.259_labels.csv  264.299_labels.csv	356.257_labels.csv  661.184_labels.csv
# 183.292_labels.csv  265.233_labels.csv	358.225_labels.csv  661.219_labels.csv
# 186.253_labels.csv  266.298_labels.csv	358.243_labels.csv  662.184_labels.csv
# 193.245_labels.csv  268.254_labels.csv	359.250_labels.csv  662.188_labels.csv
# 193.247_labels.csv  272.256_labels.csv	360.180_labels.csv  667.179_labels.csv
# 195.250_labels.csv  276.255_labels.csv	361.249_labels.csv  667.180_labels.csv
# 196.271_labels.csv  282.233_labels.csv	367.182_labels.csv  667.182_labels.csv
# 196.287_labels.csv  290.235_labels.csv	369.220_labels.csv  669.179_labels.csv
# 197.271_labels.csv  292.256_labels.csv	370.266_labels.csv  670.209_labels.csv
# 197.287_labels.csv  294.238_labels.csv	372.247_labels.csv  671.183_labels.csv
# 199.255_labels.csv  295.237_labels.csv	373.180_labels.csv  679.187_labels.csv
# 201.287_labels.csv  296.236_labels.csv	374.225_labels.csv  683.198_labels.csv
# 203.263_labels.csv  296.253_labels.csv	374.267_labels.csv  690.181_labels.csv
# 203.285_labels.csv  297.255_labels.csv	375.243_labels.csv  692.181_labels.csv
# 204.257_labels.csv  299.246_labels.csv	375.252_labels.csv  698.191_labels.csv
# 204.269_labels.csv  300.251_labels.csv	378.272_labels.csv  711.180_labels.csv
# 205.269_labels.csv  314.228_labels.csv	379.259_labels.csv  712.179_labels.csv
# 206.264_labels.csv  319.290_labels.csv	380.255_labels.csv  714.180_labels.csv
# 209.235_labels.csv  324.225_labels.csv	381.245_labels.csv

# %%
# !ls labels/stronglensdb_confirmed_unige/CFIS\ r
# Out:
# 051.245_labels.csv  206.264_labels.csv	244.284_labels.csv  277.286_labels.csv
# 068.321_labels.csv  211.252_labels.csv	244.294_labels.csv  292.256_labels.csv
# 070.320_labels.csv  212.301_labels.csv	244.296_labels.csv  294.238_labels.csv
# 147.282_labels.csv  213.274_labels.csv	245.284_labels.csv  296.253_labels.csv
# 147.288_labels.csv  214.269_labels.csv	245.289_labels.csv  297.255_labels.csv
# 154.285_labels.csv  216.250_labels.csv	245.290_labels.csv  299.246_labels.csv
# 154.286_labels.csv  217.257_labels.csv	245.297_labels.csv  300.251_labels.csv
# 156.285_labels.csv  219.264_labels.csv	246.289_labels.csv  319.290_labels.csv
# 159.283_labels.csv  222.247_labels.csv	246.291_labels.csv  328.262_labels.csv
# 162.275_labels.csv  226.273_labels.csv	247.291_labels.csv  330.260_labels.csv
# 163.275_labels.csv  227.295_labels.csv	248.272_labels.csv  333.268_labels.csv
# 164.278_labels.csv  228.262_labels.csv	249.287_labels.csv  336.239_labels.csv
# 164.282_labels.csv  229.294_labels.csv	253.263_labels.csv  337.271_labels.csv
# 165.270_labels.csv  229.296_labels.csv	253.286_labels.csv  340.274_labels.csv
# 166.281_labels.csv  230.261_labels.csv	254.287_labels.csv  342.243_labels.csv
# 167.274_labels.csv  230.265_labels.csv	256.287_labels.csv  342.271_labels.csv
# 168.268_labels.csv  230.294_labels.csv	257.285_labels.csv  347.271_labels.csv
# 175.268_labels.csv  230.296_labels.csv	258.285_labels.csv  349.267_labels.csv
# 175.271_labels.csv  231.274_labels.csv	259.286_labels.csv  351.245_labels.csv
# 179.259_labels.csv  231.289_labels.csv	260.251_labels.csv  352.268_labels.csv
# 183.292_labels.csv  232.294_labels.csv	260.284_labels.csv  355.250_labels.csv
# 186.253_labels.csv  232.295_labels.csv	261.266_labels.csv  358.243_labels.csv
# 188.307_labels.csv  233.295_labels.csv	261.285_labels.csv  370.266_labels.csv
# 193.247_labels.csv  234.295_labels.csv	262.284_labels.csv  374.267_labels.csv
# 194.305_labels.csv  235.292_labels.csv	262.285_labels.csv  375.252_labels.csv
# 195.250_labels.csv  236.293_labels.csv	263.267_labels.csv  378.272_labels.csv
# 195.307_labels.csv  236.294_labels.csv	263.299_labels.csv  379.259_labels.csv
# 196.271_labels.csv  237.291_labels.csv	264.267_labels.csv  380.255_labels.csv
# 196.287_labels.csv  238.278_labels.csv	264.284_labels.csv  386.248_labels.csv
# 197.271_labels.csv  238.291_labels.csv	264.299_labels.csv  392.250_labels.csv
# 197.287_labels.csv  238.293_labels.csv	266.298_labels.csv  393.245_labels.csv
# 199.255_labels.csv  238.294_labels.csv	267.283_labels.csv  403.238_labels.csv
# 201.287_labels.csv  239.258_labels.csv	267.284_labels.csv  403.257_labels.csv
# 201.311_labels.csv  240.258_labels.csv	268.254_labels.csv  406.250_labels.csv
# 203.263_labels.csv  240.293_labels.csv	269.283_labels.csv  407.242_labels.csv
# 203.285_labels.csv  241.290_labels.csv	272.256_labels.csv  424.243_labels.csv
# 204.257_labels.csv  242.290_labels.csv	272.283_labels.csv  442.244_labels.csv
# 204.269_labels.csv  243.290_labels.csv	273.273_labels.csv  452.239_labels.csv
# 204.278_labels.csv  243.292_labels.csv	275.272_labels.csv
# 205.269_labels.csv  244.275_labels.csv	276.255_labels.csv

# %%
ls
# Out:
#  AnaTests.ipynb                  'Multi-Channel Autoencoder.ipynb'   lenses/
# 'Create Filtered Cutouts.ipynb'  'Plot Labelled Cutouts.ipynb'
# 'Lens Binary Classifier.ipynb'    labels/

# %% [markdown]
# # Save labelled cutouts to hdf5 file

# %%
filters[0]+filters[2]
# Out:
# 'CFIS u/CFIS r/'

# %%
cutout_size = 64
for label_subdir in label_subdirs[0]:
    for f in filters:
        subdir = label_dir + label_subdir + f
        for csv in os.listdir(subdir):
            if csv != ".ipynb_checkpoints":
                tile_id = csv[:7] # XXX.XXX id
                img_group_name = label_subdir + tile_id + "/" + f + "IMAGES"
                wt_group_name = label_subdir + tile_id + "/" + f + "WEIGHTS"
        
                if img_group_name not in hf:
                    img_group = hf.create_group(img_group_name)
                    wt_group = hf.create_group(wt_group_name)
                else:
                    img_group = hf[img_group_name]
                    wt_group = hf[wt_group_name]
                tile_name = f.split(" ")[0] + "." + tile_id + "." + f.split(" ")[1][0]
                if "CFIS" in f:
                    wt_name = ".weight.fits.fz"
                    wt_index = 1
                else:
                    wt_name = ".wt.fits"
                    wt_index = 0
            
                #shutil.copy2(image_dir + tile_name + ".fits", dest)
                #shutil.copy2(image_dir + tile_name + wt_name, dest)
                img_fits = fits.open(image_dir + tile_name + ".fits", memmap=True)
                wt_fits = fits.open(image_dir + tile_name + wt_name, memmap=True)
            
                df = pd.read_csv(subdir + csv)
                nlabels = len(df)
                for n in range(nlabels):
                    x = df["x"][n]
                    y = df["y"][n]
                    img_cutout = Cutout2D(img_fits[0].data, (x, y), cutout_size, mode="partial", fill_value=0).data
                    wt_cutout = Cutout2D(wt_fits[wt_index].data, (x, y), cutout_size, mode="partial", fill_value=0).data
                
                    img_lower = np.percentile(img_cutout, 1)
                    img_upper = np.percentile(img_cutout, 99)
                    if img_lower == img_upper:
                        img_norm = np.zeros((cutout_size, cutout_size))
                    else:
                        img_norm = (img_cutout - np.min(img_cutout)) / (img_upper - img_lower)

                    if (tile_id + str(n)) not in img_group:
                        img_group.create_dataset(tile_id + str(n), data=img_norm)
                        wt_group.create_dataset(tile_id + str(n), data=wt_cutout)

                img_fits.close()
                wt_fits.close()
    print(f"Finished {label_subdir}")
# Out:
# Finished canameras2020/
# Finished huang2020a_grade_A/
# Finished huang2020a_grade_B/
# Finished huang2020a_grade_C/
# Finished huang2020b_grade_A/
# Finished huang2020b_grade_B/
# Finished huang2020b_grade_C/

# %%
hf.close()
src = os.path.expandvars("$SLURM_TMPDIR") + "/labelled_cutouts_64p.h5"
dest = os.path.expandvars("$SCRATCH") + "/"
shutil.copy2(src, dest)
# Out:
# '/scratch/anahoban/labelled_cutouts_64p.h5'

# %% [markdown]
# # Look at confirmed cutouts from random CFIS tile

# %%
subdir = label_dir + label_subdirs[0]
u_tiles = os.listdir(subdir + filters[0])
print(u_tiles)
# Out:
# ['197.271_labels.csv', '248.272_labels.csv', '203.263_labels.csv', '165.270_labels.csv', '314.228_labels.csv', '640.188_labels.csv', '050.212_labels.csv', '206.264_labels.csv', '228.262_labels.csv', '324.225_labels.csv', '009.213_labels.csv', '358.225_labels.csv', '248.235_labels.csv', '661.184_labels.csv', '340.274_labels.csv', '346.224_labels.csv', '222.232_labels.csv', '361.249_labels.csv', '367.182_labels.csv', '403.238_labels.csv', '683.198_labels.csv', '164.282_labels.csv', '264.299_labels.csv', '290.235_labels.csv', '690.181_labels.csv', '356.257_labels.csv', '442.244_labels.csv', '669.179_labels.csv', '211.252_labels.csv', '407.242_labels.csv', '162.275_labels.csv', '337.219_labels.csv', '382.241_labels.csv', '417.236_labels.csv', '424.243_labels.csv', '662.188_labels.csv', '036.186_labels.csv', '175.268_labels.csv', '209.235_labels.csv', '203.285_labels.csv', '328.225_labels.csv', '335.252_labels.csv', '667.180_labels.csv', '261.266_labels.csv', '398.226_labels.csv', '175.271_labels.csv', '253.263_labels.csv', '259.300_labels.csv', '327.231_labels.csv', '670.209_labels.csv', '033.184_labels.csv', '266.298_labels.csv', '295.237_labels.csv', '022.182_labels.csv', '380.255_labels.csv', '679.187_labels.csv', '374.225_labels.csv', '226.273_labels.csv', '204.257_labels.csv', '201.287_labels.csv', '057.252_labels.csv', '346.246_labels.csv', '328.262_labels.csv', '210.230_labels.csv', '222.247_labels.csv', '692.181_labels.csv', '356.182_labels.csv', '193.245_labels.csv', '186.253_labels.csv', '714.180_labels.csv', '339.247_labels.csv', '381.245_labels.csv', '282.233_labels.csv', '379.259_labels.csv', '276.255_labels.csv', '223.231_labels.csv', '196.271_labels.csv', '294.238_labels.csv', '260.251_labels.csv', '447.223_labels.csv', '326.253_labels.csv', '238.217_labels.csv', '358.243_labels.csv', '370.266_labels.csv', '204.269_labels.csv', '661.219_labels.csv', '469.218_labels.csv', '671.183_labels.csv', '217.257_labels.csv', '199.255_labels.csv', '386.247_labels.csv', '297.255_labels.csv', '319.290_labels.csv', '239.258_labels.csv', '336.239_labels.csv', '086.181_labels.csv', '651.180_labels.csv', '268.254_labels.csv', '018.198_labels.csv', '375.252_labels.csv', '167.274_labels.csv', '337.271_labels.csv', '034.210_labels.csv', '448.216_labels.csv', '272.256_labels.csv', '403.257_labels.csv', '641.188_labels.csv', '166.281_labels.csv', '333.268_labels.csv', '553.254_labels.csv', '229.220_labels.csv', '351.245_labels.csv', '183.292_labels.csv', '378.272_labels.csv', '347.271_labels.csv', '349.186_labels.csv', '300.251_labels.csv', '240.258_labels.csv', '168.268_labels.csv', '252.220_labels.csv', '224.234_labels.csv', '147.282_labels.csv', '345.236_labels.csv', '164.278_labels.csv', '342.243_labels.csv', '196.287_labels.csv', '013.231_labels.csv', '014.193_labels.csv', '033.183_labels.csv', '374.267_labels.csv', '299.246_labels.csv', '205.269_labels.csv', '330.260_labels.csv', '292.256_labels.csv', '373.180_labels.csv', '263.299_labels.csv', '051.245_labels.csv', '231.274_labels.csv', '214.269_labels.csv', '711.180_labels.csv', '329.253_labels.csv', '352.268_labels.csv', '352.253_labels.csv', '406.250_labels.csv', '369.220_labels.csv', '472.227_labels.csv', '372.247_labels.csv', '265.233_labels.csv', '662.184_labels.csv', '195.250_labels.csv', '296.236_labels.csv', '644.204_labels.csv', '698.191_labels.csv', '230.265_labels.csv', '326.219_labels.csv', '659.204_labels.csv', '163.275_labels.csv', '013.214_labels.csv', '179.259_labels.csv', '296.253_labels.csv', '004.180_labels.csv', '464.230_labels.csv', '230.261_labels.csv', '450.233_labels.csv', '355.250_labels.csv', '375.243_labels.csv', '327.218_labels.csv', '244.275_labels.csv', '216.250_labels.csv', '386.248_labels.csv', '219.264_labels.csv', '353.180_labels.csv', '238.278_labels.csv', '359.250_labels.csv', '712.179_labels.csv', '033.219_labels.csv', '056.182_labels.csv', '348.187_labels.csv', '393.245_labels.csv', '193.247_labels.csv', '667.182_labels.csv', '342.271_labels.c ...

# %%
subdir = label_dir + label_subdirs[0]
u_tiles = os.listdir(subdir + filters[0])
r_tiles = os.listdir(subdir + filters[1])
tile_intersection = sorted(list(set(u_tiles) & set(r_tiles)))
print(tile_intersection)
print(len(tile_intersection))
# Out:
# ['270.293_labels.csv']
# 1

# %%
tile = tile_intersection[26][:7]
u_file = fits.open(image_dir + "CFIS.{}.u.fits".format(tile))
r_file = fits.open(image_dir + "CFIS.{}.r.fits".format(tile))
r_head = r_file[0].header
u_head = u_file[0].header
r_data = r_file[0].data
u_data = u_file[0].data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-120-87263a51261e> in <module>
#       1 #tile = tile_intersection[0][:7]
#       2 tile = u_tiles[1][:-11]
# ----> 3 u_file = fits.open(image_dir + "CFIS.{}.u.fits".format(tile))
#       4 #r_file = fits.open(image_dir + "CFIS.{}.r.fits".format(tile))
#       5 #r_head = r_file[0].header
#
# ~/lensing/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     161         raise ValueError(f'Empty filename: {name!r}')
#     162
# --> 163     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     164                             lazy_load_hdus, **kwargs)
#     165
#
# ~/lensing/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     398         """
#     399
# --> 400         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     401                              save_backup=save_backup, cache=cache,
#     402                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# ~/lensing/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1049             if not isinstance(fileobj, _File):
#    1050                 # instantiate a FITS file object (ffo)
# -> 1051                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1052             # The Astropy mode is determined by the _File initializer if the
#    1053             # supplied mode was None
#
# ~/lensing/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     533                     warnings.warn(message, warning_type, stacklevel=2)
#     534
# --> 535             return function(*args, **kwargs)
#     536
#     537         return wrapper
#
# ~/lensing/lib/python3.8/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# ~/lensing/lib/python3.8/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# ~/lensing/lib/python3.8/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     395     """
#     396
# --> 397     return open(filename, mode, buffering=0)
#     398
#     399
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/anahoban/projects/rrg-kyi/astro/cfis/W3/CFIS.270.293.u.fits'

# %%
tile = u_tiles[1][:7] # 1 tile
u_file = fits.open(image_dir + "CFIS.{}.u.fits".format(tile))
u_data = u_file[0].data
u_head = u_file[0].header

# %%
channels = ["u"]#, "r"]
plot_tiles = [u_data]#, r_data]
fig, axes = plt.subplots(1,len(channels), figsize=(12,8))
for i in range(len(channels)):
    norm = ImageNormalize(plot_tiles[i], interval=ZScaleInterval())
    axes.imshow(plot_tiles[i], norm=norm)
    axes.set_title(channels[i])
#plt.savefig("../../Plots/{}_tiles.png".format(tile))

# %%
#r_wcs = WCS(r_head)
u_wcs = WCS(u_head)
#r_df = pd.read_csv(subdir + "CFIS r/{}_labels.csv".format(tile))
u_df = pd.read_csv(subdir + "CFIS u/{}_labels.csv".format(tile))
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-OBS to '2017-04-19T06:39:30.980' from MJD-OBS'. [astropy.wcs.wcs]

# %%
from astropy.coordinates import SkyCoord
x,y = utils.skycoord_to_pixel(SkyCoord(u_df["ra"], u_df["dec"], unit="deg"), u_wcs)
print((x,y))
# Out:
# (array([7816.6296067]), array([8907.02415045]))

# %%
#r_cutout = Cutout2D(r_data, (x, y), cutout_size, mode="partial", fill_value=0).data
u_cutout = Cutout2D(u_data, (x, y), cutout_size, mode="partial", fill_value=0).data

# %%
channels = ["u"]#, "r"]
plot_cutouts = [u_cutout]#, r_cutout]
fig, axes = plt.subplots(1,len(channels), figsize=(12,8))
for i in range(len(channels)):
    norm = ImageNormalize(plot_cutouts[i], interval=ZScaleInterval())
    axes.imshow(plot_cutouts[i], norm=norm)
    axes.set_title(channels[i])
#plt.savefig("Plots/{}_labelled_cutouts.png".format(tile))

# %% [markdown]
# # Plot cutouts from each resource

# %%
def get_cutouts(label_subdir, reconstruct=False):
    cutout_size = 128
    n_cutouts = 0
    for k in list(hf.get(label_subdir).keys()):
        f = list(hf.get(label_subdir + k).keys())[0]
        img_subgroup = hf.get(label_subdir + k + "/" + f + "/IMAGES")
        n_cutouts += len(img_subgroup)
       
    plot_cutouts = np.zeros((n_cutouts, cutout_size, cutout_size, 3), dtype=int)
    if "confirmed" in label_subdir:
        types = []
    n_tiles = len(list(hf.get(label_subdir).keys()))-1
    n_plots = 0
    tile_ids = list(hf.get(label_subdir).keys())
    tile_ids.pop(tile_ids.index(".ipynb_")) #remove 'ipynb' subdir
    for n in range(n_tiles):
        tile_id = tile_ids[n]
        f = list(hf.get(label_subdir + tile_id).keys())[0]
        df = pd.read_csv(label_dir + label_subdir + f + "/" + tile_id + "_labels.csv")
        img_subgroup = hf.get(label_subdir + tile_id + "/" + f + "/IMAGES")
        n_labels = len(img_subgroup)
        for i in range(n_labels):
            if "confirmed" in label_subdir:
                types.append(df["type"][i])
            cutout = np.zeros((cutout_size, cutout_size, 5))
            dataset_name = tile_id + str(i)
            filts = [f + "/" for f in list(hf.get(label_subdir + tile_id).keys())]
            filt_indices = [filter_dict.get(f) for f in filts]
            for (j, ind) in enumerate(filt_indices):
                cutout[:,:,ind] = hf.get(label_subdir + tile_id + "/" + filts[j] + "IMAGES/" + dataset_name)
            if reconstruct:
                cutout = autoencoder.predict(np.expand_dims(cutout, axis=0))[0]
            if len(filt_indices) == 1:
                if 2 in filt_indices: # red
                    cutout_r = cutout[:,:,2]
                    cutout_g = np.zeros((cutout_size, cutout_size))
                    cutout_b = np.zeros((cutout_size, cutout_size))
                elif 1 in filt_indices: # green
                    cutout_r = np.zeros((cutout_size, cutout_size))
                    cutout_g = cutout[:,:,1]
                    cutout_b = np.zeros((cutout_size, cutout_size))
                else:
                    cutout_r = np.zeros((cutout_size, cutout_size))
                    cutout_g = np.zeros((cutout_size, cutout_size))
                    cutout_b = cutout[:,:,filt_indices[0]]
                cutout_rgb = make_lupton_rgb(cutout_r, cutout_g, cutout_b, Q=10, stretch=3)
            elif len(filt_indices) == 2:
                if 2 in filt_indices: # red
                    cutout_r = cutout[:,:,2]
                else:
                    cutout_r = cutout[:,:,filt_indices[0]]
                if 1 in filt_indices: # green
                    cutout_g = cutout[:,:,1]
                else:
                    cutout_g = cutout[:,:,filt_indices[1]]
                cutout_b = np.zeros((cutout_size, cutout_size))
                cutout_rgb = make_lupton_rgb(cutout_r, cutout_g, cutout_b, Q=10, stretch=3)
            else:
                if 2 in filt_indices:
                    cutout_r = cutout[:,:,2]
                else:
                    cutout_r = cutout[:,:,filt_indices[0]]
                if 1 in filt_indices:
                    cutout_g = cutout[:,:,1]
                else:
                    cutout_g = cutout[:,:,filt_indices[1]]
                if 3 in filt_indices: # i band
                    cutout_b = cutout[:,:,3]
                else:
                    cutout_b = cutout[:,:,filt_indices[-1]]
                cutout_rgb = make_lupton_rgb(cutout_r, cutout_g, cutout_b, Q=10, stretch=3)
            plot_cutouts[n_plots,:,:,:] = cutout_rgb
            n_plots += 1
    if "confirmed" in label_subdir:
        return (plot_cutouts, types)
    else:
        return (plot_cutouts, _)

# %%
confirmed_cutouts, confirmed_types = get_cutouts(label_subdirs[2])

# %%
def custom_loss_all(y_true, y_pred):
    return keras.losses.MSE(y_true*np.sqrt(weights_all), y_pred*np.sqrt(weights_all))

# %%
autoencoder = keras.models.load_model("Models/autoencoder_128p",
                                 custom_objects={'custom_loss_all': custom_loss_all})
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-91-7764b1915324> in <module>
# ----> 1 autoencoder = keras.models.load_model("Models/autoencoder_128p",
#       2                                  custom_objects={'custom_loss_all': custom_loss_all})
#
# ~/lensing/lib/python3.8/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     184     filepath = path_to_string(filepath)
#     185     if isinstance(filepath, six.string_types):
# --> 186       loader_impl.parse_saved_model(filepath)
#     187       return saved_model_load.load(filepath, compile, options)
#     188
#
# ~/lensing/lib/python3.8/site-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     108       raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     109   else:
# --> 110     raise IOError("SavedModel file does not exist at: %s/{%s|%s}" %
#     111                   (export_dir,
#     112                    constants.SAVED_MODEL_FILENAME_PBTXT,
#
# OSError: SavedModel file does not exist at: Models/autoencoder_128p/{saved_model.pbtxt|saved_model.pb}

# %%
confirmed_reconstructed, _ = get_cutouts(label_subdirs[0], reconstruct=True)

# %%
Counter(confirmed_types)

# %%
def plot_cutouts(cutouts, figname, ncols=6, types=None):
    n_cutouts = len(cutouts)
    nrows = int(np.ceil(n_cutouts/ncols))
    fig, axes = plt.subplots(nrows, ncols, figsize=(3.1*ncols,3.4*nrows))
    n_plots = 0
    for n1 in range(nrows):
        for n2 in range(ncols):
            cutout_rgb = cutouts[n_plots]
            norm = ImageNormalize(cutout_rgb, interval=ZScaleInterval())
            axes[n1][n2].imshow(cutout_rgb)#, norm=norm)
            if types is not None:
                axes[n1][n2].set_title(types[n_plots])
            n_plots += 1     
            if n_plots == n_cutouts:
                break
        if n_plots == n_cutouts:
                break

    # delete empty axes
    for i in range(n_cutouts, nrows*ncols):
        fig.delaxes(axes.flatten()[i])
    #plt.savefig(f"Plots/{figname}")

# %%
plot_cutouts(confirmed_cutouts[:18], "confirmed_cutouts_rgb_alt.png", types=confirmed_types)

# %%
plot_cutouts(confirmed_reconstructed, "confirmed_reconstructed_rgb.png", types=confirmed_types)

# %%
plot_indices = [14, 18, 23, 37, 80, 134, 137, 154, 184, 236]
confirmed_cutouts_report = [confirmed_cutouts[i] for i in plot_indices]
confirmed_types_report = [confirmed_types[i] for i in plot_indices]
plot_cutouts(confirmed_cutouts_report, "confirmed_cutouts_rgb_report.png", ncols=5, types=confirmed_types_report)

# %%
candidate_cutouts, _ = get_cutouts(label_subdirs[1])

# %%
plot_cutouts(candidate_cutouts, "candidate_cutouts_rgb.png")

# %%
plot_indices = [20, 43, 63, 64, 88, 109, 211, 215, 368, 383]
candidate_cutouts_report = [candidate_cutouts[i] for i in plot_indices]
plot_cutouts(candidate_cutouts_report, "candidate_cutouts_rgb_report.png", ncols=5)

# %%
canameras_cutouts, _ = get_cutouts(label_subdirs[2])

# %%
plot_cutouts(canameras_cutouts, "canameras_cutouts_rgb.png")

# %%
for label_subdir in label_subdirs[3:]:
    figname = label_subdir[:-1] + ".png"
    huang_cutouts, _ = get_cutouts(label_subdir)
    plot_cutouts(huang_cutouts, figname)

# %%
def count_cutouts(label_subdir):
    n_cutouts = 0
    for k in list(hf.get(label_subdir).keys()):
        f = list(hf.get(label_subdir + k).keys())[0]
        img_subgroup = hf.get(label_subdir + k + "/" + f + "/IMAGES")
        n_cutouts += len(img_subgroup)
    print(label_subdir + ":" + str(n_cutouts))

# %%
for label_subdir in label_subdirs[:]:
    count_cutouts(label_subdir)

# %%
hf.close()
#src = os.path.expandvars("$SLURM_TMPDIR") + "/labelled_cutouts_alt.h5"
#dest = os.path.expandvars("$SCRATCH") + "/"
#shutil.copy2(src, dest)
